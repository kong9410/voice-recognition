# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import pandas as pd

df = pd.DataFrame(data=[],columns=['href'])
display(df)
# Out:
# Empty DataFrame
# Columns: [href]
# Index: []

# %%
topics=['politics','economy','social','culture','education','science','history','philosophy','sports','environment']
page =[2,2,4,1,2,2,1,1,1,1,1]

cnt=0
topics_index = 0

for topics_index in range (0,len(topics)):
    for i in range(1,page[topics_index]+1):
        if i==1:
            url = "https://debatingday.com/category/opendiscussion/"+topics[topics_index]
        else :
            url = "https://debatingday.com/category/opendiscussion/"+topics[topics_index]+"/page/"+str(i)+"/"

        html = urlopen(url)
        source = html.read() # 바이트코드 type으로 소스를 읽는다.
        html.close() # urlopen을 진행한 후에는 close를 한다.

        soup = BeautifulSoup(source, "html5lib") # 파싱할 문서를 BeautifulSoup 클래스의 생성자에 넘겨주어 문서 개체를 생성, 관습적으로 soup 이라 부름
        links = soup.find_all(class_="blog-one-item")
        for link in links:
            cnt+=1
            link_url = link.a.get('href')
            print(cnt,link_url)
            a = pd.DataFrame(data=[link_url],columns=['href'])
            df = df.append(a)
            df = df.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-3-3f43d87f929e> in <module>
#      16         html.close() # urlopen을 진행한 후에는 close를 한다.
#      17
# ---> 18         soup = BeautifulSoup(source, "html5lib") # 파싱할 문서를 BeautifulSoup 클래스의 생성자에 넘겨주어 문서 개체를 생성, 관습적으로 soup 이라 부름
#      19         links = soup.find_all(class_="blog-one-item")
#      20         for link in links:
#
# ~\Anaconda3\envs\meeting\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     206                     "Couldn't find a tree builder with the features you "
#     207                     "requested: %s. Do you need to install a parser library?"
# --> 208                     % ",".join(features))
#     209
#     210         # At this point either we have a TreeBuilder instance in
#
# ...

# %%
display(df)
# Out:
#                                                   href
# 0    https://debatingday.com/16036/%ec%9e%ac%ed%8c%...
# 1    https://debatingday.com/15615/%eb%b6%80%ec%a0%...
# 2    https://debatingday.com/15447/%eb%b0%95%ea%b7%...
# 3    https://debatingday.com/14789/%eb%8c%80%ed%86%...
# 4    https://debatingday.com/14320/%ec%9d%98%eb%ac%...
# 5    https://debatingday.com/11513/%ea%b5%ad%ed%9a%...
# 6    https://debatingday.com/10498/anonymous-is-it-...
# 7    https://debatingday.com/10468/should-wartime-o...
# 8    https://debatingday.com/10134/%ec%96%b4%eb%82%...
# 9    https://debatingday.com/9096/%ec%82%ac%eb%93%9...
# 10   https://debatingday.com/8184/%eb%82%a8%eb%b6%8...
# 11   https://debatingday.com/7975/%ea%b9%80%ec%98%8...
# 12   https://debatingday.com/7027/%ec%a0%84%ec%8b%9...
# 13   https://debatingday.com/6523/%eb%af%bc%ea%b0%8...
# 14   https://debatingday.com/4916/%eb%ac%b4%ec%83%8...
# 15   https://debatingday.com/4816/%ec%84%a0%ea%b1%b...
# ...

# %%
df.to_excel('link.xlsx',sheet_name='Sheet1')
